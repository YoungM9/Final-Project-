# %%
import pandas as pd

df = pd.read_csv('Resources/Parking_Violations_Issued_-_Fiscal_Year_2023.csv')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (17,18,20,22,23,30,31,32,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
pd.set_option('display.max_columns', None)
df.head(10)
# Out:
#    Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 0      1484697303  JER1863                 NY        PAS  06/10/2022
# 1      1484697315  KEV4487                 NY        PAS  06/13/2022
# 2      1484697625   H73NYD                 NJ        PAS  06/19/2022
# 3      1484697674  GJC9296                 NY        PAS  06/19/2022
# 4      1484697686   M51PUV                 NJ        PAS  06/19/2022
# 5      1484697698   H73NYD                 NJ        PAS  06/23/2022
# 6      1484697728   M51PUV                 NJ        PAS  06/23/2022
# 7      1484698204  KJJ8637                 NY        PAS  06/20/2022
# 8      1484698381  JEC8631                 NY        PAS  06/19/2022
# 9      1484698721   K21PNH                 NJ        PAS  06/25/2022
#
#    Violation Code Vehicle Body Type Vehicle Make Issuing Agency  Street Code1  \
# 0              67               SDN        TOYOT              P         34330
# 1              51              SUBN         JEEP              K         34310
# 2              63               SDN         JEEP              N         30640
# 3              63              SUBN        LEXUS              N         30640
# 4              63               SDN        HYUND              N         30640
# 5              63               NaN         JEEP              K         30640
# 6              63               NaN        HYUND              K         30640
# 7              67              SUBN        TOYOT              N         11585
# 8              98              SUBN        NISSA              N             0
# 9              10              SUBN         JEEP              K         33190
#
#    Street Code2  Street Code3  Vehicle Expiration Date  Violation Location  \
# 0           179             0                 20221210                10.0
# 1         16400         11010                 20220908                10.0
# 2         13015         28540                        0                 1.0
# 3         13015         28540                 20230820                 1.0
# 4         13015         28540                        0                 1.0
# 5         13015         28540                        0                 1.0
# 6         13015         28540                        0                 1.0
# 7         26390         15010                 20230120                 5.0
# 8             0             0                 20230121                10.0
# 9         25190         31990                        0                 6.0
#
#    Violation Precinct  Issuer Precinct  Issuer Code Issuer Command  \
# 0                  10                1       160195           0001
# 1                  10                1       160195           0001
# 2                   1                1       161315           0001
# 3                   1                1       161315           0001
# 4                   1                1       161315           0001
# 5                   1                1       161315           0001
# 6                   1                1       161315           0001
# 7                   5                1       160954           0001
# 8                  10                1       161348           0001
# 9                   6                1       161134           0001
#
#   Issuer Squad Violation Time Time First Observed Violation County  \
# 0          0.0          1037A                 NaN               NY
# 1          0.0          1045A                 NaN               NY
# 2          0.0          1116A                 NaN               NY
# 3          0.0          1052A                 NaN               NY
# 4          0.0          1107A                 NaN               NY
# 5          0.0          1050A                 NaN               NY
# 6          0.0          1101A                 NaN               NY
# 7          0.0          1205P                 NaN               NY
# 8          0.0          0535P                 NaN               NY
# 9          0.0          0307P                 NaN               NY
#
#   Violation In Front Of Or Opposite House Number         Street Name  \
# 0                                 F          NaN           W 28TH ST
# 1                                 O          436             27TH DR
# 2                               NaN          109            SOUTH ST
# 3                               NaN          109            SOUTH ST
# 4                               NaN          109            SOUTH ST
# 5                                 O          109            SOUTH ST
# 6                                 O          109            SOUTH ST
# 7                                 F          NaN  COLEMAN PLAYGROUND
# 8                               NaN          NaN   S/S W 28TH STREET
# 9                                 O           40    WASHINGTON SQ SO
#
#   Intersecting Street  Date First Observed  Law Section Sub Division  \
# 0          CHELSEA PK                    0          408           E3
# 1                 NaN                    0          408           F3
# 2                 NaN                    0          408           F3
# 3                 NaN                    0          408           F3
# 4                 NaN                    0          408           F3
# 5                 NaN                    0          408           E3
# 6                 NaN                    0          408           F3
# 7                 NaN                    0          408           E3
# 8      W/O 9TH AVENUE                    0          408            B
# 9                 NaN                    0          408            B
#
#   Violation Legal Code Days Parking In Effect     From Hours In Effect  \
# 0                  NaN                    BBBBBBB                  ALL
# 1                  NaN                    BBBBBBB                  ALL
# 2                  NaN                    BBBBBBB                  ALL
# 3                  NaN                    BBBBBBB                  ALL
# 4                  NaN                    BBBBBBB                  ALL
# 5                  NaN                    BBBBBBB                  ALL
# 6                  NaN                    BBBBBBB                  ALL
# 7                  NaN                    BBBBBBB                  ALL
# 8                  NaN                    BBBBBBB                  ALL
# 9                  NaN                    BBBBBBB                  ALL
#
#   To Hours In Effect Vehicle Color  Unregistered Vehicle?  Vehicle Year  \
# 0                ALL           BLK                    0.0          2004
# 1                ALL          GRAY                    0.0          2017
# 2                ALL          GRAY                    0.0             0
# 3                ALL           NaN                    0.0             0
# 4                ALL          BLUE                    0.0             0
# 5                ALL           NaN                    0.0             0
# 6                ALL          BLUE                    0.0             0
# 7                ALL         WHITE                    0.0          2021
# 8                ALL           BLK                    0.0          2002
# 9                ALL           RED                    0.0             0
#
#   Meter Number  Feet From Curb Violation Post Code Violation Description  \
# 0            -               0                 NaN                   NaN
# 1            -               0                 NaN                   NaN
# 2            -               0                 NaN                   NaN
# 3            -               0                 NaN                   NaN
# 4            -               0                 NaN                   NaN
# 5            -               0                 NaN                   NaN
# 6            -               0                 NaN                   NaN
# 7            -               0                 NaN                   NaN
# 8            -               0                 NaN                   NaN
# 9            -               0                 NaN                   NaN
#
#    No Standing or Stopping Violation  Hydrant Violation  \
# 0                                NaN                NaN
# 1                                NaN                NaN
# 2                                NaN                NaN
# 3                                NaN                NaN
# 4                                NaN                NaN
# 5                                NaN                NaN
# 6                                NaN                NaN
# 7                                NaN                NaN
# 8                                NaN                NaN
# 9                                NaN                NaN
#
#    Double Parking Violation
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN

# %%
len(df.index)
# Out:
# 457255

# %%
df.isna().sum()
# Out:
# Summons Number                            0
# Plate ID                                 14
# Registration State                        0
# Plate Type                                0
# Issue Date                                0
# Violation Code                            0
# Vehicle Body Type                      2165
# Vehicle Make                           1145
# Issuing Agency                            0
# Street Code1                              0
# Street Code2                              0
# Street Code3                              0
# Vehicle Expiration Date                   0
# Violation Location                   191935
# Violation Precinct                        0
# Issuer Precinct                           0
# Issuer Code                               0
# Issuer Command                       191095
# Issuer Squad                         235318
# Violation Time                           19
# Time First Observed                  403304
# Violation County                       3616
# Violation In Front Of Or Opposite    199424
# House Number                         202042
# Street Name                             160
# Intersecting Street                  229452
# Date First Observed                       0
# Law Section                               0
# Sub Division                            168
# Violation Legal Code                 266159
# Days Parking In Effect               201203
# From Hours In Effect                 289212
# To Hours In Effect                   289212
# Vehicle Color                         21000
# Unregistered Vehicle?                425479
# Vehicle Year                              0
# Meter Number                         395465
# Feet From Curb                            0
# Violation Post Code                  267094
# Violation Description                 31802
# No Standing or Stopping Violation    457255
# Hydrant Violation                    457255
# Double Parking Violation             457255
# dtype: int64

# %%
dropped_df = df.drop(['Unregistered Vehicle?', 'No Standing or Stopping Violation', 'Hydrant Violation', 'Double Parking Violation', \
                      'Issuer Precinct', 'Issuer Code', 'Issuer Command', 'Issuer Squad', 'Intersecting Street', 'Issuing Agency', \
                      'Law Section', 'Sub Division', 'Violation Legal Code', 'Violation Precinct', 'Violation Description', \
                      'Feet From Curb', 'Meter Number', 'To Hours In Effect', 'From Hours In Effect', \
                      'Violation Legal Code', 'Sub Division', 'Violation County', 'Violation In Front Of Or Opposite', 'House Number', \
                      'Violation Post Code', 'Time First Observed', 'Date First Observed', 'Street Code1', 'Street Code2', 'Street Code3',\
                      'Plate ID', 'Summons Number', 'Issue Date', 'Days Parking In Effect    '], axis = 1)

# %%
dropped_df.head(10)
# Out:
#   Registration State Plate Type  Violation Code Vehicle Body Type  \
# 0                 NY        PAS              67               SDN
# 1                 NY        PAS              51              SUBN
# 2                 NJ        PAS              63               SDN
# 3                 NY        PAS              63              SUBN
# 4                 NJ        PAS              63               SDN
# 5                 NJ        PAS              63               NaN
# 6                 NJ        PAS              63               NaN
# 7                 NY        PAS              67              SUBN
# 8                 NY        PAS              98              SUBN
# 9                 NJ        PAS              10              SUBN
#
#   Vehicle Make  Vehicle Expiration Date  Violation Location Violation Time  \
# 0        TOYOT                 20221210                10.0          1037A
# 1         JEEP                 20220908                10.0          1045A
# 2         JEEP                        0                 1.0          1116A
# 3        LEXUS                 20230820                 1.0          1052A
# 4        HYUND                        0                 1.0          1107A
# 5         JEEP                        0                 1.0          1050A
# 6        HYUND                        0                 1.0          1101A
# 7        TOYOT                 20230120                 5.0          1205P
# 8        NISSA                 20230121                10.0          0535P
# 9         JEEP                        0                 6.0          0307P
#
#           Street Name Vehicle Color  Vehicle Year
# 0           W 28TH ST           BLK          2004
# 1             27TH DR          GRAY          2017
# 2            SOUTH ST          GRAY             0
# 3            SOUTH ST           NaN             0
# 4            SOUTH ST          BLUE             0
# 5            SOUTH ST           NaN             0
# 6            SOUTH ST          BLUE             0
# 7  COLEMAN PLAYGROUND         WHITE          2021
# 8   S/S W 28TH STREET           BLK          2002
# 9    WASHINGTON SQ SO           RED             0

# %%
dropped_df.dtypes
# Out:
# Registration State             object
# Plate Type                     object
# Violation Code                  int64
# Vehicle Body Type              object
# Vehicle Make                   object
# Vehicle Expiration Date         int64
# Violation Location            float64
# Violation Time                 object
# Street Name                    object
# Days Parking In Effect         object
# Vehicle Color                  object
# Vehicle Year                    int64
# dtype: object

# %%
dropped_df = dropped_df.dropna()
# Out:
# '...'

# %%
dropped_df['Plate Type'].count()
# Out:
# 260321

# %%
dropped_df['Plate Type'].value_counts()
# Out:
# PAS    247732
# OMS      3357
# COM      2763
# OMT      2042
# 999      1876
# SRF      1324
# SPO       186
# MOT       166
# ORG       123
# TRL        92
# OMR        87
# LMB        82
# APP        68
# MED        67
# RGL        62
# TOW        36
# MCL        35
# NYC        29
# PHS        24
# HIS        22
# TRA        18
# VAS        18
# SCL        15
# NYS        15
# ITP        12
# TRC        11
# OML        10
# DLR         7
# SRN         7
# IRP         6
# OMV         3
# AGC         3
# CMB         3
# PSD         3
# SEM         3
# CHC         2
# VPL         2
# NLM         2
# NYA         1
# JSC         1
# CSP         1
# STA         1
# HAM         1
# LTR         1
# RGC         1
# ORC         1
# Name: Plate Type, dtype: int64

# %%
#Plate Type Registration State Jun
plates_types = {
    'PAS': 1
    ''
}

# %%
#Vehicle Color Encoded

# %%
#Vehicle Expiration Date, Violation Time into Date Time

# %%
#Vehicle Make and Body Type Encoded
